# %% [markdown]
# <a href="https://colab.research.google.com/github/xmamadaliyeva/python_lessons/blob/main/2amaliy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("sample_data/financial_regression.csv")
df.head()
print("Satrlar soni:", df.shape[0])
print("Ustunlar soni:", df.shape[1])
# Out:
# Satrlar soni: 3904
# Ustunlar soni: 47

# %%
df_clean = df.dropna()
df_clean.shape
# Out:
# (30, 47)

# %%
df_clean
# Out:
#             date  sp500 open  sp500 high  sp500 low  sp500 close  \
# 55    2010-04-01      117.80    118.2500     117.10       117.80
# 121   2010-07-01      103.15    103.4900     101.13       102.76
# 188   2010-10-01      114.99    115.1200     113.93       114.61
# 319   2011-04-01      133.41    133.7700     132.83       133.15
# 385   2011-07-01      132.09    134.1000     131.78       133.92
# 716   2012-10-01      144.52    145.6900     144.01       144.35
# 847   2013-04-01      156.59    156.9100     155.67       156.05
# 913   2013-07-01      161.26    162.4800     161.08       161.36
# 980   2013-10-01      168.14    169.5000     167.97       169.34
# 1113  2014-04-01      187.62    188.3600     187.00       188.25
# 1179  2014-07-01      196.20    197.6300     196.13       197.03
# 1245  2014-10-01      196.70    196.7700     193.91       194.35
# 1378  2015-04-01      206.43    206.4300     204.51       205.70
# ...
